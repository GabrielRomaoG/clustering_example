# %% [markdown]
# # Analise Exploratória

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from etl import preprocess_localiza_data

# %%
data = preprocess_localiza_data(carros_csv="data/carros.csv", vendas_csv="data/vendas.csv")

# %%
data.describe()
# Out:
#               idade  tempo_no_estoque   kilometragem  valor_a_vista  \
# count  76392.000000      76392.000000   76392.000000   7.639200e+04
# mean      45.421000         39.376453   45998.578320   2.220006e+05
# std       13.807663         41.607426   19555.558691   9.561504e+05
# min       18.000000          0.000000       0.000000   0.000000e+00
# 25%       35.000000         10.000000   36686.250000   0.000000e+00
# 50%       44.000000         24.000000   45211.500000   8.560000e+03
# 75%       54.000000         54.000000   54210.250000   4.017250e+04
# max       95.000000        540.000000  886170.000000   2.031533e+07
#
#        desconto_percentual  valor_parcela   qt_parcelas   recomprador  \
# count         76392.000000   7.639200e+04  76392.000000  76392.000000
# mean              0.035148   8.072149e+04     25.645513      0.191106
# std               0.015992   9.381028e+04     24.171059      0.393175
# min               0.000000   0.000000e+00      1.000000      0.000000
# ...

# %%
categorical_columns = data.select_dtypes('object').columns.to_list()
categorical_columns.remove("modelo")

for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(y=column, data=data)
    plt.title(f"Quantidade por {column}")
    plt.show()

# %%
numerical_columns = data.select_dtypes('number').columns

for column in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=data, x=column)
    plt.title(f"Histograma da {column}")
    plt.show()
